# %% [markdown]
# <a href="https://colab.research.google.com/github/ORychok/homeworks/blob/main/Rychok_%22hw_3_4_apply%2C_groupby%2C_pivot_table_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data_path = '../content/drive/MyDrive/Python/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df[['gross income', 'Branch']].groupby('Branch').sum()
# Out:
#         gross income
# Branch
# A          5057.1605
# B          5057.0320
# C          5265.1765

# %% [markdown]
# Найприбутковішим є Branch "С".

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
res1 = pd.pivot_table(df, index='City', columns='Branch', values=['gross income'], aggfunc="sum").round(2)
res1
# Out:
#           gross income
# Branch               A        B        C
# City
# Mandalay           NaN  5057.03      NaN
# Naypyitaw          NaN      NaN  5265.18
# Yangon         5057.16      NaN      NaN

# %% [markdown]
# Філіал з найвищим прибутком знаходиться в місті Naypyitaw.
# З даних бачу, що в кожному місті є по 1 філіалу.
# Підстав для розміщення ще одного магазину в місті Naypyitaw немає, як на мене.

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index='Branch', columns='Product line', values=['gross income'], aggfunc='count')
invoices_by_category
# Out:
#                        gross income                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Branch
# A                                60                  51                 58
# B                                55                  62                 50
# C                                55                  65                 66
#
#
# Product line Health and beauty Home and lifestyle Sports and travel
# Branch
# A                           47                 65                59
# B                           53                 50                62
# C                           52                 45                45

# %%
display(invoices_by_category.columns)
# Out:
# MultiIndex([('gross income', 'Electronic accessories'),
#             ('gross income',    'Fashion accessories'),
#             ('gross income',     'Food and beverages'),
#             ('gross income',      'Health and beauty'),
#             ('gross income',     'Home and lifestyle'),
#             ('gross income',      'Sports and travel')],
#            names=[None, 'Product line'])

# %%
invoices_by_category.columns = invoices_by_category.columns.droplevel(0)
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
display(invoices_by_category.columns)
# Out:
# Index(['Electronic accessories', 'Fashion accessories', 'Food and beverages',
#        'Health and beauty', 'Home and lifestyle', 'Sports and travel'],
#       dtype='object', name='Product line')

# %%
invoices_by_category.max().sort_values(ascending=False).head(1)
# Out:
# Product line
# Food and beverages    66
# dtype: int64

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# Гіпотеза 1.
#
# Чи правда, що customer type 'Member' є лояльнішим і приносить більше прибутку для бізнесу?
#
# Ні, не правда.
# gross margin percentage однаковий незалежно від типу покупця. Різниця у gross income складає лише 3%.

# %%
h1 = pd.pivot_table(df, index='Customer type', values=['gross income'], aggfunc="sum").round(2)
h1
# Out:
#                gross income
# Customer type
# Member              7820.16
# Normal              7559.20

# %%
h1_1 = pd.pivot_table(df, index='Customer type', values=['gross margin percentage'], aggfunc="mean").round(2)
h1_1
# Out:
#                gross margin percentage
# Customer type
# Member                            4.76
# Normal                            4.76

# %% [markdown]
# Гіпотеза 2.
#
# Чи правда, що жінки роблять покупки частіше за чоловіків та приносить більше прибутку для бізнесу?
#
# Жінки роблять покупки з однаковою частотою, як і чоловіки. Однак для жінок середній чек вищий приблизно на 8%, як і в результаті вища загальна сума gross income теж на 8%.

# %%
df[['Gender','gross income']].groupby('Gender').agg(['count', 'sum', 'mean']).round(2)
# Out:
#        gross income
#               count      sum   mean
# Gender
# Female          501  7994.42  15.96
# Male            499  7384.94  14.80

# %% [markdown]
# Гіпотеза 3.
#
# Чи правда, що жінки мають більше товарів у чеку?
#
# Так, правда, жінки в середньому мають на 8% більше товарів у своїй корзині. При цьому середня ціна товарів у корзинах приблизно однакова для обох гендерів.

# %%
pd.pivot_table(df, index=['Gender'], aggfunc={'Quantity': ['mean', 'sum'],'Unit price': 'mean'}).round(2)
# Out:
#        Quantity       Unit price
#            mean   sum       mean
# Gender
# Female     5.73  2869      55.26
# Male       5.29  2641      56.08
